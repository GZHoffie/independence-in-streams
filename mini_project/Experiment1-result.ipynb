# %% [markdown]
# # Experiment 1 Results

# %%
import pandas as pd
import numpy as np

df_random = pd.read_csv("results/counter_matrix_l2_random.csv")

# %%
df_zipfian = pd.read_csv("results/counter_matrix_l2_zipfian.csv")

# %%
A_length = 5
B_length = 5

A_range = 2 ** np.arange(A_length+1)[1:]
B_range = 4 ** np.arange(B_length)

def get_A_B_Table(df,is_dependent):
    df_result = pd.DataFrame([0*np.arange(A_length)], columns=A_range, index=B_range,dtype=np.float64)
    for A in A_range:
        for B in B_range:
            rows = df[(df['A'] == A) & (df['B'] == B) & (df['is_independent'] == is_dependent)]
            if len(rows)>=1:
                df_result[A][B] = rows["error"].mean()
    return df_result

# %%
get_A_B_Table(df_random,'dependent')
# Out:
#            2         4         8         16        32
# 1    0.450537  0.192048  0.053852  0.023916  0.015661
# 4    0.414036  0.141648  0.053533  0.025423  0.007171
# 16   0.239866  0.063814  0.026485  0.009675  0.004532
# 64   0.297715  0.052855  0.021604  0.006910  0.005641
# 256  0.288948  0.057999  0.018541  0.008588  0.001205

# %%
get_A_B_Table(df_random,'independent')
# Out:
#            2         4         8         16        32
# 1    0.401140  0.292316  0.100423  0.051171  0.017768
# 4    0.224761  0.118114  0.019799  0.012302  0.011697
# 16   0.286748  0.052774  0.008510  0.012821  0.008939
# 64   0.328810  0.025917  0.022485  0.007506  0.002322
# 256  0.295032  0.011417  0.021785  0.003699  0.002610

# %%
get_A_B_Table(df_zipfian,'dependent')
# Out:
#            2         4         8         16        32
# 1    0.561978  0.116835  0.053566  0.026087  0.005170
# 4    0.241000  0.055140  0.040690  0.014915  0.005655
# 16   0.203792  0.037948  0.012536  0.007444  0.003694
# 64   0.230859  0.037576  0.005997  0.002579  0.001762
# 256  0.203329  0.028557  0.009255  0.001563  0.002044

# %%
get_A_B_Table(df_zipfian,'independent')
# Out:
#            2         4         8         16        32
# 1    0.567727  0.117505  0.082284  0.038022  0.014242
# 4    0.465189  0.039366  0.031472  0.023964  0.014675
# 16   0.352457  0.068149  0.017812  0.016407  0.011978
# 64   0.311025  0.040865  0.025680  0.018174  0.011105
# 256  0.285863  0.029304  0.013811  0.013607  0.010472
