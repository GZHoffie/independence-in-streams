# %% [markdown]
# # Experiments

# %% [markdown]
# ## Generate samples

# %%
from mini_project.algorithms.counter_matrix import L2Estimator, L1Estimator
from mini_project.utils import check_error
import numpy as np
import pandas as pd


def test_l2(test_file,n,N,is_dependent,A,B):
    estimator = L2Estimator(A, B)
    (res, answer, error) = check_error(estimator, test_file,"l2")
    print("error:", error)
    with open('results/counter_matrix_l2_random.csv', 'a') as f:
        f.write(f"{n},{N},{is_dependent},{A},{B},{res},{answer},{error}\n")

df = pd.read_csv("results/counter_matrix_l2_random.csv")


n = 10000
N = 1000000
total_times = 5
        
A_range = 2 ** np.arange(6)[1:]
B_range = 4 ** np.arange(5)

print(A_range,A_range.shape)
print(B_range,B_range.shape)

for i in range(total_times):
    for is_dependent in['dependent','independent']:
        test_file = f"{n}-{N}-{is_dependent}-radom"
        print(test_file)
        for A in A_range:
            for B in B_range:
                if len(df[(df['A'] == A) & (df['B'] == B)& (df['is_independent']==is_dependent)])>i:
                    print(f"Skip A={A}, B={B}")
                else:
                    print("l2",test_file,n,N,is_dependent,A,B)
                    test_l2(test_file,n,N,is_dependent,A,B)
# Out:
# [ 2  4  8 16 32] (5,)
# [  1   4  16  64 256] (5,)
# 10000-1000000-dependent-radom
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# Skip A=32, B=1
# Skip A=32, B=4
# Skip A=32, B=16
# Skip A=32, B=64
# Skip A=32, B=256
# 10000-1000000-independent-radom
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# l2 10000-1000000-independent-radom 10000 1000000 independent 32 1
# variance: 0.0
# Estimator result: 0.00101250509100014
# Answer: 0.000999886492398402
# error: 0.012620031071197024
# l2 10000-1000000-independent-radom 10000 1000000 independent 32 4
# variance: 4.62242120412696e-15
# Estimator result: 0.0009832945597464786
# Answer: 0.000999886492398402
# error: 0.016593816176198928
# l2 10000-1000000-independent-radom 10000 1000000 independent 32 16
# variance: 2.2734228312350722e-15
# Estimator result: 0.000983528336853868
# Answer: 0.000999886492398402
# error: 0.01636001253031849
# l2 10000-1000000-independent-radom 10000 1000000 independent 32 64
# variance: 1.8811978834914146e-15
# Estimator result: 0.001005568079224075
# Answer: 0.000999886492398402
# error: 0.0056822318021767515
# l2 10000-1000000-independent-radom 10000 1000000 independent 32 256
# variance: 2.3605503246235816e-15
# Estimator result: 0.000995530580712426
# Answer: 0.000999886492398402
# error: 0.00435640617119204
# 10000-1000000-dependent-radom
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 4 256
