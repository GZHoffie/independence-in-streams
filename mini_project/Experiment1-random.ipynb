# %% [markdown]
# # Experiments

# %% [markdown]
# ## Generate samples

# %%
from mini_project.algorithms.counter_matrix import L2Estimator, L1Estimator
from mini_project.utils import check_error
import numpy as np
import pandas as pd


def test_l2(test_file,n,N,is_dependent,A,B):
    estimator = L2Estimator(A, B)
    (res, answer, error) = check_error(estimator, test_file,"l2")
    print("error:", error)
    with open('results/counter_matrix_l2_random.csv', 'a') as f:
        f.write(f"{n},{N},{is_dependent},{A},{B},{res},{answer},{error}\n")



n = 10000
N = 1000000
total_times = 5
        
A_range = 2 ** np.arange(6)[1:]
B_range = 4 ** np.arange(5)

print(A_range,A_range.shape)
print(B_range,B_range.shape)

for i in range(total_times):
    for is_dependent in['dependent','independent']:
        test_file = f"{n}-{N}-{is_dependent}-radom"
        print(test_file)
        for A in A_range:
            for B in B_range:
                df = pd.read_csv("results/counter_matrix_l2_random.csv")
                if len(df[(df['A'] == A) & (df['B'] == B)& (df['is_independent']==is_dependent)])>i:
                    print(f"Skip A={A}, B={B}")
                else:
                    print("l2",test_file,n,N,is_dependent,A,B)
                    test_l2(test_file,n,N,is_dependent,A,B)
# Out:
# [ 2  4  8 16 32] (5,)
# [  1   4  16  64 256] (5,)
# 10000-1000000-dependent-radom
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# Skip A=32, B=1
# Skip A=32, B=4
# Skip A=32, B=16
# Skip A=32, B=64
# Skip A=32, B=256
# 10000-1000000-independent-radom
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# Skip A=32, B=1
# Skip A=32, B=4
# Skip A=32, B=16
# Skip A=32, B=64
# Skip A=32, B=256
# 10000-1000000-dependent-radom
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# Skip A=32, B=1
# Skip A=32, B=4
# Skip A=32, B=16
# Skip A=32, B=64
# Skip A=32, B=256
# 10000-1000000-independent-radom
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# l2 10000-1000000-independent-radom 10000 1000000 independent 16 256
# variance: 1.0033739127634496e-14
# Estimator result: 0.0009921322729594504
# Answer: 0.000999886492398402
# error: 0.007755099701718948
# Skip A=32, B=1
# Skip A=32, B=4
# Skip A=32, B=16
# Skip A=32, B=64
# l2 10000-1000000-independent-radom 10000 1000000 independent 32 256
# variance: 2.1848057043183994e-15
# Estimator result: 0.0010008028890245188
# Answer: 0.000999886492398402
# error: 0.0009165006559082034
# 10000-1000000-dependent-radom
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 2 256
# variance: 1.5619608215870714e-12
# Estimator result: 0.0006679385211659718
# Answer: 0.0010016305745224907
# error: 0.3331488293631617
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 4 256
# variance: 2.741330981661599e-13
# Estimator result: 0.0009613544955383272
# Answer: 0.0010016305745224907
# error: 0.04021051274654275
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# Skip A=32, B=1
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 32 4
# variance: 1.4436318323441394e-15
# Estimator result: 0.0009942980282033223
# Answer: 0.0010016305745224907
# error: 0.007320609519796295
# Skip A=32, B=16
# Skip A=32, B=64
# Skip A=32, B=256
# 10000-1000000-independent-radom
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# l2 10000-1000000-independent-radom 10000 1000000 independent 4 1
# variance: 0.0
# Estimator result: 0.0014019009335982633
# Answer: 0.000999886492398402
# error: 0.4020600780750221
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# l2 10000-1000000-independent-radom 10000 1000000 independent 8 1
# variance: 0.0
# Estimator result: 0.00088301291322526
# Answer: 0.000999886492398402
# error: 0.11688684671877136
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# l2 10000-1000000-independent-radom 10000 1000000 independent 16 1
# variance: 0.0
# Estimator result: 0.0008687987213363011
# Answer: 0.000999886492398402
# error: 0.1311026522097164
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# l2 10000-1000000-independent-radom 10000 1000000 independent 32 1
# variance: 0.0
# Estimator result: 0.0010145557083582244
# Answer: 0.000999886492398402
# error: 0.01467088121636273
# Skip A=32, B=4
# Skip A=32, B=16
# Skip A=32, B=64
# Skip A=32, B=256
# 10000-1000000-dependent-radom
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 2 1
# variance: 0.0
# Estimator result: 0.0005564012400000318
# Answer: 0.0010016305745224907
# error: 0.44450453674970336
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 2 4
# variance: 1.5019297243211603e-14
# Estimator result: 0.0002002875663951937
# Answer: 0.0010016305745224907
# error: 0.8000384857554121
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 2 16
# variance: 1.38379559287513e-12
# Estimator result: 0.00047292730849846223
# Answer: 0.0010016305745224907
# error: 0.5278425793622346
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 2 64
# variance: 1.061710592263805e-12
# Estimator result: 0.0005423358029503364
# Answer: 0.0010016305745224907
# error: 0.45854707639202674
# Skip A=2, B=256
# Skip A=4, B=1
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 4 4
# variance: 1.4202216518959707e-13
# Estimator result: 0.0008125575582284711
# Answer: 0.0010016305745224907
# error: 0.18876522053468336
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=8, B=1
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 8 4
# variance: 9.701260528029283e-15
# Estimator result: 0.0008949277589963335
# Answer: 0.0010016305745224907
# error: 0.10652911187043768
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 16 1
# variance: 0.0
# Estimator result: 0.0010109571159819526
# Answer: 0.0010016305745224907
# error: 0.009311358595366581
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 32 1
# variance: 0.0
# Estimator result: 0.001004233557903643
# Answer: 0.0010016305745224907
# error: 0.0025987459322447393
# Skip A=32, B=4
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 32 16
# variance: 1.7355183288263887e-15
# Estimator result: 0.0010016213032635222
# Answer: 0.0010016305745224907
# error: 9.256166099813612e-06
# Skip A=32, B=64
# Skip A=32, B=256
# 10000-1000000-independent-radom
# Skip A=2, B=1
# l2 10000-1000000-independent-radom 10000 1000000 independent 2 4
# variance: 1.5030063880021566e-11
# Estimator result: 0.0013971009935579764
# Answer: 0.000999886492398402
# error: 0.3972595931432039
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# l2 10000-1000000-independent-radom 10000 1000000 independent 4 4
# variance: 3.935370751085592e-14
# Estimator result: 0.0009468271310574351
# Answer: 0.000999886492398402
# error: 0.05306538466550814
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=8, B=1
# l2 10000-1000000-independent-radom 10000 1000000 independent 8 4
# variance: 2.2666948627754802e-14
# Estimator result: 0.0010046934627498322
# Answer: 0.000999886492398402
# error: 0.0048075160410456785
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# Skip A=32, B=1
# l2 10000-1000000-independent-radom 10000 1000000 independent 32 4
# variance: 2.634618059580183e-15
# Estimator result: 0.0010244924981505385
# Answer: 0.000999886492398402
# error: 0.02460879903789359
# Skip A=32, B=16
# Skip A=32, B=64
# Skip A=32, B=256
# 10000-1000000-dependent-radom
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# Skip A=4, B=4
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 4 16
# variance: 1.9269872214262077e-13
# Estimator result: 0.0009568723852661638
# Answer: 0.0010016305745224907
# error: 0.04468532650140444
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 4 64
# variance: 2.90116570934316e-13
# Estimator result: 0.0009609375120462393
# Answer: 0.0010016305745224907
# error: 0.04062681742283181
# Skip A=4, B=256
# Skip A=8, B=1
# Skip A=8, B=4
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 8 16
# variance: 3.569693569755284e-14
# Estimator result: 0.0009919412254694245
# Answer: 0.0010016305745224907
# error: 0.00967357556720494
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 8 64
# variance: 5.343215024509922e-14
# Estimator result: 0.0009581672332892862
# Answer: 0.0010016305745224907
# error: 0.0433925863873762
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 16 16
# variance: 6.831066477923886e-15
# Estimator result: 0.0009985978521261049
# Answer: 0.0010016305745224907
# error: 0.003027785366707225
# Skip A=16, B=64
# Skip A=16, B=256
# Skip A=32, B=1
# Skip A=32, B=4
# Skip A=32, B=16
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 32 64
# variance: 2.168858891159073e-15
# Estimator result: 0.0009984704423247025
# Answer: 0.0010016305745224907
# error: 0.0031549877551358962
# Skip A=32, B=256
# 10000-1000000-independent-radom
# Skip A=2, B=1
# Skip A=2, B=4
# l2 10000-1000000-independent-radom 10000 1000000 independent 2 16
# variance: 3.4190847503153783e-12
# Estimator result: 0.0007250775389137249
# Answer: 0.000999886492398402
# error: 0.27484014993091854
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# Skip A=32, B=1
# Skip A=32, B=4
# l2 10000-1000000-independent-radom 10000 1000000 independent 32 16
# variance: 1.2571369388904024e-15
# Estimator result: 0.001002595221665508
# Answer: 0.000999886492398402
# error: 0.0027090367633717527
# l2 10000-1000000-independent-radom 10000 1000000 independent 32 64
# variance: 2.2082383786511698e-15
# Estimator result: 0.0010000960123362007
# Answer: 0.000999886492398402
# error: 0.00020954372260417742
# Skip A=32, B=256
