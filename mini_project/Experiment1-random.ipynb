# %% [markdown]
# # Experiments

# %% [markdown]
# ## Generate samples

# %%
from mini_project.algorithms.counter_matrix import L2Estimator, L1Estimator
from mini_project.utils import check_error
import numpy as np
import pandas as pd


def test_l2(test_file,n,N,is_dependent,A,B):
    estimator = L2Estimator(A, B)
    (res, answer, error) = check_error(estimator, test_file,"l2")
    print("error:", error)
    with open('results/counter_matrix_l2_random.csv', 'a') as f:
        f.write(f"{n},{N},{is_dependent},{A},{B},{res},{answer},{error}\n")

df = pd.read_csv("results/counter_matrix_l2_random.csv")


        
n = 10000
N = 1000000
        
A_range = 2 ** np.arange(5)[1:]
B_range = 4 ** np.arange(5)

print(A_range,A_range.shape)
print(B_range,B_range.shape)


for is_dependent in['dependent','independent']:
    test_file = f"{n}-{N}-{is_dependent}-radom"
    print(test_file)
    for A in A_range:
        for B in B_range:
            if len(df[(df['A'] == A) & (df['B'] == B)& (df['is_independent']==is_dependent)])>=1:
                print(f"Skip A={A}, B={B}")
            else:
                print("l2",test_file,n,N,is_dependent,A,B)
                test_l2(test_file,n,N,is_dependent,A,B)
# Out:
# [ 2  4  8 16] (4,)
# [  1   4  16  64 256] (5,)
# 10000-1000000-dependent-radom
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# 10000-1000000-independent-radom
# l2 10000-1000000-independent-radom 10000 1000000 independent 2 1
# variance: 0.0
# Estimator result: 0.00038079331599999433
# Answer: 0.000999886492398402
# error: 0.6191634561573132
# l2 10000-1000000-independent-radom 10000 1000000 independent 2 4
# variance: 3.2743474951437622e-12
# Estimator result: 0.0009819185892653726
# Answer: 0.000999886492398402
# error: 0.017969942858144017
# l2 10000-1000000-independent-radom 10000 1000000 independent 2 16
# variance: 3.3338104614600946e-13
# Estimator result: 0.0006838803050938506
# Answer: 0.000999886492398402
# error: 0.3160420604808407
# l2 10000-1000000-independent-radom 10000 1000000 independent 2 64
# variance: 2.4182609872464817e-12
# Estimator result: 0.0006305455859802615
# Answer: 0.000999886492398402
# error: 0.36938283417771944
# l2 10000-1000000-independent-radom 10000 1000000 independent 2 256
# variance: 2.3344663924131816e-12
# Estimator result: 0.000654195782043464
# Answer: 0.000999886492398402
# error: 0.34572995333274126
# l2 10000-1000000-independent-radom 10000 1000000 independent 4 1
# variance: 0.0
# Estimator result: 0.001299185922571346
# Answer: 0.000999886492398402
# error: 0.29933340679002685
# l2 10000-1000000-independent-radom 10000 1000000 independent 4 4
# variance: 2.7809906908710985e-14
# Estimator result: 0.0010004653428104598
# Answer: 0.000999886492398402
# error: 0.0005789161234386331
# l2 10000-1000000-independent-radom 10000 1000000 independent 4 16
# variance: 1.638808576203279e-13
# Estimator result: 0.0010998721391930143
# Answer: 0.000999886492398402
# error: 0.09999699721393318
# l2 10000-1000000-independent-radom 10000 1000000 independent 4 64
# variance: 3.35143999493159e-13
# Estimator result: 0.0010393780855597122
# Answer: 0.000999886492398402
# error: 0.039496076266199776
# l2 10000-1000000-independent-radom 10000 1000000 independent 4 256
# variance: 2.301958705116945e-13
# Estimator result: 0.001011188886271885
# Answer: 0.000999886492398402
# error: 0.01130367692674028
# l2 10000-1000000-independent-radom 10000 1000000 independent 8 1
# variance: 0.0
# Estimator result: 0.0010352153293306022
# Answer: 0.000999886492398402
# error: 0.03533284747897514
# l2 10000-1000000-independent-radom 10000 1000000 independent 8 4
# variance: 2.52158354932655e-14
# Estimator result: 0.0009948916434417458
# Answer: 0.000999886492398402
# error: 0.004995415974342388
# l2 10000-1000000-independent-radom 10000 1000000 independent 8 16
# variance: 1.4601912522708663e-14
# Estimator result: 0.0010000502029133222
# Answer: 0.000999886492398402
# error: 0.00016372909941764213
# l2 10000-1000000-independent-radom 10000 1000000 independent 8 64
# variance: 3.114469583786776e-14
# Estimator result: 0.000945637936000125
# Answer: 0.000999886492398402
# error: 0.05425471472082033
# l2 10000-1000000-independent-radom 10000 1000000 independent 8 256
# variance: 3.666069975114418e-14
# Estimator result: 0.000978369768546131
# Answer: 0.000999886492398402
# error: 0.021519166441242077
# l2 10000-1000000-independent-radom 10000 1000000 independent 16 1
# variance: 0.0
# Estimator result: 0.0010061341085870837
# Answer: 0.000999886492398402
# error: 0.006248325421114309
# l2 10000-1000000-independent-radom 10000 1000000 independent 16 4
# variance: 4.329055517926301e-15
# Estimator result: 0.0009590739471509547
# Answer: 0.000999886492398402
# error: 0.0408171783074609
# l2 10000-1000000-independent-radom 10000 1000000 independent 16 16
# variance: 9.373871545020089e-15
# Estimator result: 0.0009954346180107872
# Answer: 0.000999886492398402
# error: 0.00445237976656343
# l2 10000-1000000-independent-radom 10000 1000000 independent 16 64
# variance: 9.543173842380163e-15
# Estimator result: 0.0010020761728167151
# Answer: 0.000999886492398402
# error: 0.002189928991900736
# l2 10000-1000000-independent-radom 10000 1000000 independent 16 256
# variance: 8.226029601961036e-15
# Estimator result: 0.0010003428111953548
# Answer: 0.000999886492398402
# error: 0.000456370598484801

# %%
df = pd.read_csv("results/counter_matrix_l2_random.csv")

A_range = 2 ** np.arange(7)[1:]
B_range = 4 ** np.arange(6)

print(A_range,A_range.shape)
print(B_range,B_range.shape)


for is_dependent in['dependent','independent']:
    test_file = f"{n}-{N}-{is_dependent}-radom"
    print(test_file)
    for A in A_range:
        for B in B_range:
            if len(df[(df['A'] == A) & (df['B'] == B)& (df['is_independent']==is_dependent)])>=1:
                print(f"Skip A={A}, B={B}")
            else:
                print("l2",test_file,n,N,is_dependent,A,B)
                test_l2(test_file,n,N,is_dependent,A,B)
# Out:
# [ 2  4  8 16 32 64] (6,)
# [   1    4   16   64  256 1024] (6,)
# 10000-1000000-dependent-radom
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=2, B=1024
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=4, B=1024
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# l2 10000-1000000-dependent-radom 10000 1000000 dependent 8 1024

# %%
df = pd.read_csv("results/counter_matrix_l2_random.csv")

A_range = 2 ** np.arange(7)[1:]
B_range = 4 ** np.arange(7)

print(A_range,A_range.shape)
print(B_range,B_range.shape)


for is_dependent in['dependent','independent']:
    test_file = f"{n}-{N}-{is_dependent}-radom"
    print(test_file)
    for A in A_range:
        for B in B_range:
            if len(df[(df['A'] == A) & (df['B'] == B)])>=1:
                print(f"Skip A={A}, B={B}")
            else:
                print("l2",test_file,n,N,is_dependent,A,B)
                test_l2(test_file,n,N,is_dependent,A,B)

# %%
df = pd.read_csv("results/counter_matrix_l2_random.csv")

A_range = 2 ** np.arange(8)[1:]
B_range = 4 ** np.arange(7)

print(A_range,A_range.shape)
print(B_range,B_range.shape)


for is_dependent in['dependent','independent']:
    test_file = f"{n}-{N}-{is_dependent}-radom"
    print(test_file)
    for A in A_range:
        for B in B_range:
            if len(df[(df['A'] == A) & (df['B'] == B)& (df['is_independent']==is_dependent)])>=1:
                print(f"Skip A={A}, B={B}")
            else:
                print("l2",test_file,n,N,is_dependent,A,B)
                test_l2(test_file,n,N,is_dependent,A,B)
