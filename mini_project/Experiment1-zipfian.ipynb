# %% [markdown]
# # Experiments

# %% [markdown]
# ## Generate samples

# %%
from mini_project.algorithms.counter_matrix import L2Estimator, L1Estimator
from mini_project.utils import check_error
import numpy as np
import pandas as pd


def test_l2(test_file,n,N,is_dependent,A,B):
    estimator = L2Estimator(A, B)
    (res, answer, error) = check_error(estimator, test_file,"l2")
    print("error:", error)
    with open('results/counter_matrix_l2_zipfian.csv', 'a') as f:
        f.write(f"{n},{N},{is_dependent},{A},{B},{res},{answer},{error}\n")

        
n = 10000
N = 1000000

df = pd.read_csv("results/counter_matrix_l2_zipfian.csv")
        
A_range = 2 ** np.arange(5)[1:]
B_range = 4 ** np.arange(5)

print(A_range,A_range.shape)
print(B_range,B_range.shape)


for is_dependent in['dependent','independent']:
    test_file = f"{n}-{N}-{is_dependent}-zipfian"
    print(test_file)
    for A in A_range:
        for B in B_range:
            if len(df[(df['A'] == A) & (df['B'] == B)& (df['is_independent']==is_dependent)])>=1:
                print(f"Skip A={A}, B={B}")
            else:
                print("l2",test_file,n,N,is_dependent,A,B)
                test_l2(test_file,n,N,is_dependent,A,B)
# Out:
# [ 2  4  8 16] (4,)
# [  1   4  16  64 256] (5,)
# 10000-1000000-dependent-zipfian
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# 10000-1000000-independent-zipfian
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 2 64
# variance: 9.328043497352468e-13
# Estimator result: 0.0006182159838747899
# Answer: 0.000987850754854881
# error: 0.3741807850664566
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 2 256
# variance: 1.4065259735659101e-12
# Estimator result: 0.0006403153979768319
# Answer: 0.000987850754854881
# error: 0.35180957768170495
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 4 1
# variance: 0.0
# Estimator result: 0.0009210556524411195
# Answer: 0.000987850754854881
# error: 0.0676165929777256
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 4 4
# variance: 5.262336750096387e-14
# Estimator result: 0.000976911590950397
# Answer: 0.000987850754854881
# error: 0.011073701012751846
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 4 16
# variance: 1.419828685630784e-13
# Estimator result: 0.0010329781811456034
# Answer: 0.000987850754854881
# error: 0.04568243337259159
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 4 64
# variance: 1.4718645193755353e-13
# Estimator result: 0.0009606788966152719
# Answer: 0.000987850754854881
# error: 0.02750603581165534
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 4 256
# variance: 2.3137088823008545e-13
# Estimator result: 0.0009548434902638411
# Answer: 0.000987850754854881
# error: 0.03341320986882157
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 8 1
# variance: 0.0
# Estimator result: 0.0010177708140856358
# Answer: 0.000987850754854881
# error: 0.030288036005145402
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 8 4
# variance: 2.1394908056101516e-14
# Estimator result: 0.0009550428926949699
# Answer: 0.000987850754854881
# error: 0.03321135505406447
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 8 16
# variance: 5.2620000276566695e-14
# Estimator result: 0.00100077117157523
# Answer: 0.000987850754854881
# error: 0.013079320592559673
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 8 64
# variance: 3.664892366338926e-14
# Estimator result: 0.0009730827957428267
# Answer: 0.000987850754854881
# error: 0.014949585288542733
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 8 256
# variance: 4.363608719377155e-14
# Estimator result: 0.0009658572246107855
# Answer: 0.000987850754854881
# error: 0.022264021296745873
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 16 1
# variance: 0.0
# Estimator result: 0.0009402758222932695
# Answer: 0.000987850754854881
# error: 0.04816004070230273
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 16 4
# variance: 3.2270457253260988e-15
# Estimator result: 0.0010065138103614107
# Answer: 0.000987850754854881
# error: 0.018892586167301495
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 16 16
# variance: 8.394752750526537e-15
# Estimator result: 0.0009726638002430667
# Answer: 0.000987850754854881
# error: 0.015373733873438544
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 16 64
# variance: 9.68684005704068e-15
# Estimator result: 0.0009794227757890068
# Answer: 0.000987850754854881
# error: 0.008531631953970997
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 16 256
# variance: 1.3485302585021131e-14
# Estimator result: 0.0009779012249124615
# Answer: 0.000987850754854881
# error: 0.010071895874474657

# %%
df = pd.read_csv("results/counter_matrix_l2_zipfian.csv")
        
A_range = 2 ** np.arange(7)[1:]
B_range = 4 ** np.arange(6)

print(A_range,A_range.shape)
print(B_range,B_range.shape)


for is_dependent in['dependent','independent']:
    test_file = f"{n}-{N}-{is_dependent}-zipfian"
    print(test_file)
    for A in A_range:
        for B in B_range:
            if len(df[(df['A'] == A) & (df['B'] == B)& (df['is_independent']==is_dependent)])>=1:
                print(f"Skip A={A}, B={B}")
            else:
                print("l2",test_file,n,N,is_dependent,A,B)
                test_l2(test_file,n,N,is_dependent,A,B)
# Out:
# [ 2  4  8 16 32 64] (6,)
# [   1    4   16   64  256 1024] (6,)
# 10000-1000000-dependent-zipfian
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=2, B=1024
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=4, B=1024
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# l2 10000-1000000-dependent-zipfian 10000 1000000 dependent 8 1024

# %%
df = pd.read_csv("results/counter_matrix_l2_zipfian.csv")
        
A_range = 2 ** np.arange(7)[1:]
B_range = 4 ** np.arange(7)

print(A_range,A_range.shape)
print(B_range,B_range.shape)


for is_dependent in['dependent','independent']:
    test_file = f"{n}-{N}-{is_dependent}-zipfian"
    print(test_file)
    for A in A_range:
        for B in B_range:
            if len(df[(df['A'] == A) & (df['B'] == B)& (df['is_independent']==is_dependent)])>=1:
                print(f"Skip A={A}, B={B}")
            else:
                print("l2",test_file,n,N,is_dependent,A,B)
                test_l2(test_file,n,N,is_dependent,A,B)

# %%
df = pd.read_csv("results/counter_matrix_l2_zipfian.csv")
        
A_range = 2 ** np.arange(8)[1:]
B_range = 4 ** np.arange(7)

print(A_range,A_range.shape)
print(B_range,B_range.shape)


for is_dependent in['dependent','independent']:
    test_file = f"{n}-{N}-{is_dependent}-zipfian"
    print(test_file)
    for A in A_range:
        for B in B_range:
            if len(df[(df['A'] == A) & (df['B'] == B)& (df['is_independent']==is_dependent)])>=1:
                print(f"Skip A={A}, B={B}")
            else:
                print("l2",test_file,n,N,is_dependent,A,B)
                test_l2(test_file,n,N,is_dependent,A,B)
