# %% [markdown]
# # Experiments

# %% [markdown]
# ## Generate samples

# %%
from mini_project.algorithms.counter_matrix import L2Estimator, L1Estimator
from mini_project.utils import check_error
import numpy as np
import pandas as pd


def test_l2(test_file,n,N,is_dependent,A,B):
    estimator = L2Estimator(A, B)
    (res, answer, error) = check_error(estimator, test_file,"l2")
    print("error:", error)
    with open('results/counter_matrix_l2_zipfian.csv', 'a') as f:
        f.write(f"{n},{N},{is_dependent},{A},{B},{res},{answer},{error}\n")

        
n = 10000
N = 1000000
total_times = 5

df = pd.read_csv("results/counter_matrix_l2_zipfian.csv")
        
A_range = 2 ** np.arange(6)[1:]
B_range = 4 ** np.arange(5)

print(A_range,A_range.shape)
print(B_range,B_range.shape)


for i in range(total_times):
    for is_dependent in['dependent','independent']:
        test_file = f"{n}-{N}-{is_dependent}-zipfian"
        print(test_file)
        for A in A_range:
            for B in B_range:
                if len(df[(df['A'] == A) & (df['B'] == B)& (df['is_independent']==is_dependent)])>i:
                    print(f"Skip A={A}, B={B}")
                else:
                    print("l2",test_file,n,N,is_dependent,A,B)
                    test_l2(test_file,n,N,is_dependent,A,B)
# Out:
# [ 2  4  8 16 32] (5,)
# [  1   4  16  64 256] (5,)
# 10000-1000000-dependent-zipfian
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# Skip A=32, B=1
# Skip A=32, B=4
# Skip A=32, B=16
# Skip A=32, B=64
# l2 10000-1000000-dependent-zipfian 10000 1000000 dependent 32 256
# variance: 2.852185459405213e-08
# Estimator result: 0.06526841728520703
# Answer: 0.0651095740530614
# error: 0.002439629416346234
# 10000-1000000-independent-zipfian
# Skip A=2, B=1
# Skip A=2, B=4
# Skip A=2, B=16
# Skip A=2, B=64
# Skip A=2, B=256
# Skip A=4, B=1
# Skip A=4, B=4
# Skip A=4, B=16
# Skip A=4, B=64
# Skip A=4, B=256
# Skip A=8, B=1
# Skip A=8, B=4
# Skip A=8, B=16
# Skip A=8, B=64
# Skip A=8, B=256
# Skip A=16, B=1
# Skip A=16, B=4
# Skip A=16, B=16
# Skip A=16, B=64
# Skip A=16, B=256
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 32 1
# variance: 0.0
# Estimator result: 0.0009658369112548802
# Answer: 0.000987850754854881
# error: 0.022284584479803082
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 32 4
# variance: 5.478083799105387e-15
# Estimator result: 0.0009635962600583488
# Answer: 0.000987850754854881
# error: 0.024552792693968484
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 32 16
# variance: 2.3316166476595716e-15
# Estimator result: 0.0009724474907587245
# Answer: 0.000987850754854881
# error: 0.015592703675586406
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 32 64
# variance: 3.7344704096077184e-15
# Estimator result: 0.0009849638551696549
# Answer: 0.000987850754854881
# error: 0.002922404696294678
# l2 10000-1000000-independent-zipfian 10000 1000000 independent 32 256
