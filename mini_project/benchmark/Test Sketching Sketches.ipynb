# %%
from mini_project.algorithms.sketching_sketches import L2Estimator, L1Estimator
from mini_project.utils import check_error
import numpy as np

def test_l1(test_file,n,N,is_dependent,delta,s):
    estimator = L1Estimator(delta, s, n)
    (res, answer, error) = check_error(estimator, test_file)
    print("error:", error)
    with open('results/sketching_sketches_l1.csv', 'a') as f:
        f.write(f"{n},{N},{is_dependent},{res},{answer},{error},{delta},{s}\n")

def test_l2(test_file,n,N,is_dependent,A,B):
    estimator = L2Estimator(A, B, n)
    (res, answer, error) = check_error(estimator, test_file)
    print("error:", error)
    with open('results/sketching_sketches_l2.csv', 'a') as f:
        f.write(f"{n},{N},{is_dependent},{res},{answer},{error},{A},{B}\n")

# n_range = [10,10**2,10**3,10**4,10**5,10**6,10**7]
# N_range = [10**3,10**4,10**5,10**6,10**7,10**8]
        
n_range = [10**4]
N_range = [10**5]
l1_delta_range = [0.001,0.0001,0.00001,0.000001,0.0000001,0.0000000001]
l1_s_range = range(1000,9000,3000)
l2_A_range = range(100,1000,300)
l2_B_range = range(100,1000,300)


for n in n_range:
    for N in N_range :
        for is_dependent in['dependent','independent']:
            test_file = f"{n}-{N}-{is_dependent}"
            print(test_file)
            for delta in l1_delta_range:
                for s in l1_s_range:
                    print("l1",test_file,n,N,is_dependent,delta,s)
                    test_l1(test_file,n,N,is_dependent,delta,s)
            for A in l2_A_range:
                for B in l2_B_range:
                    print("l2",test_file,n,N,is_dependent,A,B)
                    test_l2(test_file,n,N,is_dependent,A,B)
# Out:
# 10000-100000-dependent
# l1 10000-100000-dependent 10000 100000 dependent 0.001 1000
# error: 14263.980598844571
# l1 10000-100000-dependent 10000 100000 dependent 0.001 4000
# error: 11130.975150342712
# l1 10000-100000-dependent 10000 100000 dependent 0.001 7000
# error: 8217.785689071266
# l1 10000-100000-dependent 10000 100000 dependent 0.0001 1000
# error: 7897.775129284205
# l1 10000-100000-dependent 10000 100000 dependent 0.0001 4000
# error: 9553.31300775928
# l1 10000-100000-dependent 10000 100000 dependent 0.0001 7000
# error: 16467.944405557348
# l1 10000-100000-dependent 10000 100000 dependent 1e-05 1000
# error: 13991.60001054742
# l1 10000-100000-dependent 10000 100000 dependent 1e-05 4000
# error: 20415.049030422302
# l1 10000-100000-dependent 10000 100000 dependent 1e-05 7000
# error: 9694.194480022741
# l1 10000-100000-dependent 10000 100000 dependent 1e-06 1000
# error: 13463.647384384705
# l1 10000-100000-dependent 10000 100000 dependent 1e-06 4000
# error: 8642.160379705834
# l1 10000-100000-dependent 10000 100000 dependent 1e-06 7000
# error: 10008.341055468218
# l1 10000-100000-dependent 10000 100000 dependent 1e-07 1000
# error: 13238.004798944063
# l1 10000-100000-dependent 10000 100000 dependent 1e-07 4000
# error: 10423.69379568777
# l1 10000-100000-dependent 10000 100000 dependent 1e-07 7000
# error: 15474.586938312079
# l1 10000-100000-dependent 10000 100000 dependent 1e-10 1000
# error: 8799.56513152996
# l1 10000-100000-dependent 10000 100000 dependent 1e-10 4000
# error: 12737.224097924529
# l1 10000-100000-dependent 10000 100000 dependent 1e-10 7000
# error: 21296.318854015106
# l2 10000-100000-dependent 10000 100000 dependent 100 100
# error: 0.003023866639131789
# l2 10000-100000-dependent 10000 100000 dependent 100 400
# error: 0.0003580850215140208
# l2 10000-100000-dependent 10000 100000 dependent 100 700
# error: 0.0003556230881958111
# l2 10000-100000-dependent 10000 100000 dependent 400 100
# error: 0.00497048760503338
# l2 10000-100000-dependent 10000 100000 dependent 400 400
# error: 0.0009560162884717505
# l2 10000-100000-dependent 10000 100000 dependent 400 700
# error: 0.001242685081340733
# l2 10000-100000-dependent 10000 100000 dependent 700 100
# error: 0.0026783554372723506
# l2 10000-100000-dependent 10000 100000 dependent 700 400
# error: 0.0015277194522629323
# l2 10000-100000-dependent 10000 100000 dependent 700 700
# error: 0.0015496251129965
# 10000-100000-independent
# l1 10000-100000-independent 10000 100000 independent 0.001 1000
# error: 17509.842895848196
# l1 10000-100000-independent 10000 100000 independent 0.001 4000
# error: 11532.498303279543
# l1 10000-100000-independent 10000 100000 independent 0.001 7000
# error: 6961.795653365054
# l1 10000-100000-independent 10000 100000 independent 0.0001 1000
# error: 14819.963213221541
# l1 10000-100000-independent 10000 100000 independent 0.0001 4000
# error: 15905.117544819434
# l1 10000-100000-independent 10000 100000 independent 0.0001 7000
# error: 16199.576633519993
# l1 10000-100000-independent 10000 100000 independent 1e-05 1000
# error: 13466.016095451574
# l1 10000-100000-independent 10000 100000 independent 1e-05 4000
# error: 9784.40274393316
# l1 10000-100000-independent 10000 100000 independent 1e-05 7000
# error: 12490.35584023284
# l1 10000-100000-independent 10000 100000 independent 1e-06 1000
# error: 15954.711609709506
# l1 10000-100000-independent 10000 100000 independent 1e-06 4000
# error: 9343.39238891544
# l1 10000-100000-independent 10000 100000 independent 1e-06 7000
# error: 12529.691604694768
# l1 10000-100000-independent 10000 100000 independent 1e-07 1000
# error: 14589.51850899155
# l1 10000-100000-independent 10000 100000 independent 1e-07 4000
# error: 15339.910304207633
# l1 10000-100000-independent 10000 100000 independent 1e-07 7000
# error: 9337.377295315007
# l1 10000-100000-independent 10000 100000 independent 1e-10 1000
# error: 10635.45746642806
# l1 10000-100000-independent 10000 100000 independent 1e-10 4000
# error: 11846.50405774088
# l1 10000-100000-independent 10000 100000 independent 1e-10 7000
# error: 15046.332557359898
# l2 10000-100000-independent 10000 100000 independent 100 100
# error: 0.0057262036642767855
# l2 10000-100000-independent 10000 100000 independent 100 400
# error: 0.014015135784282262
# l2 10000-100000-independent 10000 100000 independent 100 700
# error: 0.0025630979551799493
# l2 10000-100000-independent 10000 100000 independent 400 100
# error: 3.779475886633854e-05
# l2 10000-100000-independent 10000 100000 independent 400 400
# error: 0.00022973559731265247
# l2 10000-100000-independent 10000 100000 independent 400 700
# error: 0.00043139444760331713
# l2 10000-100000-independent 10000 100000 independent 700 100
# error: 0.003219524118814654
# l2 10000-100000-independent 10000 100000 independent 700 400
# error: 0.0006238462228138619
# l2 10000-100000-independent 10000 100000 independent 700 700
# error: 0.002606336926653352

# %% [markdown]
# ## Load results

# %%
import pandas as pd

df_l1 = pd.read_csv("results/sketching_sketches_l1.csv")
df_l1.head(100)
# Out:
#      n      N is_independent  estimated    answer      error         delta  \
# 0   10  10000      dependent   0.469696  0.056737   7.278513  1.000000e-03
# 1   10  10000      dependent   3.786469  0.056737  65.737487  1.000000e-03
# 2   10  10000      dependent   0.362608  0.056737   5.391059  1.000000e-03
# 3   10  10000      dependent   0.238348  0.056737   3.200937  1.000000e-03
# 4   10  10000      dependent   0.256395  0.056737   3.519023  1.000000e-03
# ..  ..    ...            ...        ...       ...        ...           ...
# 95  10  10000    independent   0.004737  0.008544   0.445574  1.000000e-07
# 96  10  10000    independent   0.007669  0.008544   0.102480  1.000000e-07
# 97  10  10000    independent   0.005537  0.008544   0.351897  1.000000e-07
# 98  10  10000    independent   0.014669  0.008544   0.716875  1.000000e-07
# 99  10  10000    independent   0.012042  0.008544   0.409386  1.000000e-10
#
#        s
# 0   1000
# 1   2000
# 2   3000
# 3   4000
# 4   5000
# ..   ...
# 95  6000
# 96  7000
# 97  8000
# 98  9000
# 99  1000
#
# [100 rows x 8 columns]

# %%
import pandas as pd

df_l1 = pd.read_csv("results/sketching_sketches_l2.csv")
df_l1.head(100)
# Out:
#      n      N is_independent  estimated    answer     error    A    B
# 0   10  10000      dependent   0.056837  0.056737  0.001759  100  100
# 1   10  10000      dependent   0.056378  0.056737  0.006330  100  200
# 2   10  10000      dependent   0.056451  0.056737  0.005034  100  300
# 3   10  10000      dependent   0.056507  0.056737  0.004044  100  400
# 4   10  10000      dependent   0.056511  0.056737  0.003976  100  500
# ..  ..    ...            ...        ...       ...       ...  ...  ...
# 95  10  10000    independent   0.008528  0.008544  0.001874  200  600
# 96  10  10000    independent   0.008524  0.008544  0.002365  200  700
# 97  10  10000    independent   0.008549  0.008544  0.000536  200  800
# 98  10  10000    independent   0.008552  0.008544  0.000889  200  900
# 99  10  10000    independent   0.008527  0.008544  0.002025  300  100
#
# [100 rows x 8 columns]
