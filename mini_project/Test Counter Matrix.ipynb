# %%
from mini_project.algorithms.counter_matrix import L2Estimator, L1Estimator
from mini_project.utils import check_error
import numpy as np

def test_l1(test_file,n,N,is_dependent,A,B):
    estimator = L1Estimator(A, B)
    (res, answer, error) = check_error(estimator, test_file,"l1")
    print("error:", error)
    with open('results/counter_matrix_l1.csv', 'a') as f:
        f.write(f"{n},{N},{is_dependent},{res},{answer},{error},{A},{B}\n")

def test_l2(test_file,n,N,is_dependent,A,B):
    estimator = L2Estimator(A, B)
    (res, answer, error) = check_error(estimator, test_file,"l2")
    print("error:", error)
    with open('results/counter_matrix_l2.csv', 'a') as f:
        f.write(f"{n},{N},{is_dependent},{res},{answer},{error},{A},{B}\n")

# n_range = [10,10**2,10**3,10**4,10**5,10**6,10**7]
# N_range = [10**3,10**4,10**5,10**6,10**7,10**8]
        
n_range = [10**3,10**4]
N_range = [10**4,10**5,10**6]
A_range = range(100,1000,300)
B_range = range(100,1000,300)


for n in n_range:
    for N in N_range :
        for is_dependent in['dependent','independent']:
            test_file = f"{n}-{N}-{is_dependent}"
            print(test_file)
            for A in A_range:
                for B in B_range:
                    print("l1",test_file,n,N,is_dependent,A,B)
                    test_l1(test_file,n,N,is_dependent,A,B)
            for A in A_range:
                for B in B_range:
                    print("l2",test_file,n,N,is_dependent,A,B)
                    test_l2(test_file,n,N,is_dependent,A,B)
# Out:
# 1000-10000-dependent
# l1 1000-10000-dependent 1000 10000 dependent 100 100
# error: 0.6014569171239537
# l1 1000-10000-dependent 1000 10000 dependent 100 400
# error: 0.5972271985390025
# l1 1000-10000-dependent 1000 10000 dependent 100 700
# error: 0.5984291418076284
# l1 1000-10000-dependent 1000 10000 dependent 400 100
# error: 0.058484816554151386
# l1 1000-10000-dependent 1000 10000 dependent 400 400
# error: 0.05832826750919462
# l1 1000-10000-dependent 1000 10000 dependent 400 700
# error: 0.05837345410727679
# l1 1000-10000-dependent 1000 10000 dependent 700 100
# error: 0.01668332717958987
# l1 1000-10000-dependent 1000 10000 dependent 700 400
# error: 0.016404627577219943
# l1 1000-10000-dependent 1000 10000 dependent 700 700
# error: 0.016380835036997943
# l2 1000-10000-dependent 1000 10000 dependent 100 100
# error: 0.0006682900440788675
# l2 1000-10000-dependent 1000 10000 dependent 100 400
# error: 0.00033438021311571475
# l2 1000-10000-dependent 1000 10000 dependent 100 700
# error: 0.0009252839469493512
# l2 1000-10000-dependent 1000 10000 dependent 400 100
# error: 0.00013783736530148527
# l2 1000-10000-dependent 1000 10000 dependent 400 400
# error: 0.00010128022500854872
# l2 1000-10000-dependent 1000 10000 dependent 400 700
# error: 2.4875226771303716e-05
# l2 1000-10000-dependent 1000 10000 dependent 700 100
# error: 0.000226872150532742
# l2 1000-10000-dependent 1000 10000 dependent 700 400
# error: 5.832162131147456e-05
# l2 1000-10000-dependent 1000 10000 dependent 700 700
# error: 0.00014435836381654354
# 1000-10000-independent
# l1 1000-10000-independent 1000 10000 independent 100 100
# error: 0.5974514050742835
# l1 1000-10000-independent 1000 10000 independent 100 400
# error: 0.5952961589880421
# l1 1000-10000-independent 1000 10000 independent 100 700
# error: 0.593836981101178
# l1 1000-10000-independent 1000 10000 independent 400 100
# error: 0.06769374974757403
# l1 1000-10000-independent 1000 10000 independent 400 400
# error: 0.06691036434671205
# l1 1000-10000-independent 1000 10000 independent 400 700
# error: 0.06547541119238587
# l1 1000-10000-independent 1000 10000 independent 700 100
# error: 0.020985077625981674
# l1 1000-10000-independent 1000 10000 independent 700 400
# error: 0.019342938722100245
# l1 1000-10000-independent 1000 10000 independent 700 700
# error: 0.019489715703069455
# l2 1000-10000-independent 1000 10000 independent 100 100
# error: 0.00023987253205470793
# l2 1000-10000-independent 1000 10000 independent 100 400
# error: 0.0006545744392132402
# l2 1000-10000-independent 1000 10000 independent 100 700
# error: 0.0003220228481948251
# l2 1000-10000-independent 1000 10000 independent 400 100
# error: 3.724993554377054e-05
# l2 1000-10000-independent 1000 10000 independent 400 400
# error: 0.00012015059101844194
# l2 1000-10000-independent 1000 10000 independent 400 700
# error: 0.0001486847202469832
# l2 1000-10000-independent 1000 10000 independent 700 100
# error: 0.00021784023600979197
# l2 1000-10000-independent 1000 10000 independent 700 400
# error: 0.0001125247240909566
# l2 1000-10000-independent 1000 10000 independent 700 700
# error: 0.00013240447400231226
# 1000-100000-dependent
# l1 1000-100000-dependent 1000 100000 dependent 100 100
# error: 0.8571912812676434
# l1 1000-100000-dependent 1000 100000 dependent 100 400
# error: 0.8566041447778172
# l1 1000-100000-dependent 1000 100000 dependent 100 700
# error: 0.8570256698066372
# l1 1000-100000-dependent 1000 100000 dependent 400 100
# error: 0.4240398854929983
# l1 1000-100000-dependent 1000 100000 dependent 400 400
# error: 0.4237601191705149
# l1 1000-100000-dependent 1000 100000 dependent 400 700
# error: 0.4233858300185229
# l1 1000-100000-dependent 1000 100000 dependent 700 100
# error: 0.13877470403048275
# l1 1000-100000-dependent 1000 100000 dependent 700 400
# error: 0.13889169725003625
# l1 1000-100000-dependent 1000 100000 dependent 700 700
# error: 0.1383548273587133
# l2 1000-100000-dependent 1000 100000 dependent 100 100
# error: 8.650974569002212e-05
# l2 1000-100000-dependent 1000 100000 dependent 100 400
# error: 0.0005206257882548471
# l2 1000-100000-dependent 1000 100000 dependent 100 700
# error: 0.0005368139209476208
# l2 1000-100000-dependent 1000 100000 dependent 400 100
# error: 3.535639333240859e-05
# l2 1000-100000-dependent 1000 100000 dependent 400 400

# %% [markdown]
# ## Load results

# %%
import pandas as pd

df_l1 = pd.read_csv("results/sketching_sketches_l1.csv")
df_l1.head(100)

# %%
import pandas as pd

df_l1 = pd.read_csv("results/sketching_sketches_l2.csv")
df_l1.head(100)
